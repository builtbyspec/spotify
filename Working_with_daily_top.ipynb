# %%
# %matplotlib inline

# %%
import spotipy
spotify = spotipy.Spotify()
import sys
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
from bs4 import BeautifulSoup
import requests
import lxml
import spotfuncs 
import json
filepath = "/Users/ramanyakkala/Spec/credentials.txt"
sp = spotfuncs.get_spotify_credentials(filepath)

# %%
df = pd.read_csv("/Volumes/SD_Card/daily_top_acoustic.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Position                  Track Name         Artist  Streams  \
# 0           0       1.0  Reggaetón Lento (Bailemos)           CNCO  19272.0
# 1           1       2.0                    Chantaje        Shakira  19270.0
# 2           2       3.0   Otra Vez (feat. J Balvin)  Zion & Lennox  15761.0
# 3           3       4.0                Vente Pa' Ca   Ricky Martin  14954.0
# 4           4       5.0                      Safari       J Balvin  14269.0
#
#                                                  URL        Date Region  \
# 0  https://open.spotify.com/track/3AEZUABDXNtecAO...  2017-01-01     ec
# 1  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  2017-01-01     ec
# 2  https://open.spotify.com/track/3QwBODjSEzelZyV...  2017-01-01     ec
# 3  https://open.spotify.com/track/7DM4BPaS7uofFul...  2017-01-01     ec
# 4  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  2017-01-01     ec
#
# ...

# %%
df_us = df[df["Region"] == "us"]

# %%
top_20_us = df_us["Artist"].value_counts().iloc[1:20]

# %%
top_20_us.index
# Out:
# Index(['Drake', 'XXXTENTACION', 'Kendrick Lamar', 'Khalid', 'Travis Scott',
#        'Migos', 'Lil Uzi Vert', 'Kodak Black', 'The Weeknd', 'Future',
#        'The Chainsmokers', '21 Savage', 'Ed Sheeran', 'Imagine Dragons',
#        'Juice WRLD', 'J. Cole', 'Ariana Grande', 'Cardi B', 'Billie Eilish'],
#       dtype='object')

# %%
top_20_us_world = df[df["Artist"].isin(top_20_us.index)]

# %%
top_20_us_world.groupby(['Region','Artist']).size()
# Out:
# Region  Artist
# ar      Ariana Grande       1042
#         Billie Eilish        215
#         Cardi B              357
#         Drake                780
#         Ed Sheeran          3972
#         Future                19
#         Imagine Dragons     1247
#         Juice WRLD             6
#         Kendrick Lamar       119
#         The Chainsmokers    1124
#         The Weeknd           695
#         Travis Scott           6
#         XXXTENTACION         543
# at      21 Savage            274
#         Ariana Grande       1139
#         Billie Eilish        640
#         Cardi B              522
#         Drake               1895
#         Ed Sheeran          3595
#         Future               463
#         Imagine Dragons     2215
#         J. Cole               94
#         Juice WRLD           323
#         Kendrick Lamar       845
#         Khalid               928
#         Kodak Black          193
#         Lil Uzi Vert         497
#         Migos                418
# ...
