# %% [markdown]
# Credit of spotfuncs goes to Alice Harpole
#
# http://harpolea.github.io/2018-05-09-spotipy

# %%
import spotipy
spotify = spotipy.Spotify()
import sys
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
from bs4 import BeautifulSoup
import requests
import lxml
import spotfuncs

# %% [markdown]
# Make a file called __credientials.txt__ in some other folder (not spotify folder)
#
# with format...
#
# client_id ########
# <br>
# client_secret #######

# %%
filepath = "/Users/ramanyakkala/Spec/credentials.txt"

# %%
rap_caviar = spotfuncs.get_spotify_playlist_data(playlist="RapCaviar", credentials_file=filepath)
# Out:
# headers {'Authorization': 'Bearer BQA4_rxAVxWirmhIW6dpsJf26t4aG2R50oH4bA8y-LWlkpUgsw8UnevHRAoVNeNcctCy_qdMj8Rsewn1bK0', 'Content-Type': 'application/json'}
# http status 200
# GET https://api.spotify.com/v1/users/spotify/playlists?limit=50&offset=0
# ...

# %%
rap_caviar
# Out:
#                                                                                      album  \
# track_name
# MIDDLE CHILD                                                                  MIDDLE CHILD
# Going Bad (feat. Drake)                                                      Championships
# Wow.                                                                                  Wow.
# Space Cadet (feat. Gunna)                                        NOT ALL HEROES WEAR CAPES
# First Off (feat. Travis Scott)                           Future Hndrxx Presents: The WIZRD
# Keanu Reeves                                                                  Keanu Reeves
# Splashin                                                                          Splashin
# Sauce!                                         XXXTENTACION Presents: Members Only, Vol. 4
# a lot                                                                         i am > i was
# ...
