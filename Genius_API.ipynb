# %%
import spotipy
spotify = spotipy.Spotify()
import sys
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
from bs4 import BeautifulSoup
import requests
import lxml
import spotfuncs

# %%
filepath = "/Users/ramanyakkala/Spec/genius.txt"

# %%
artist_id = spotfuncs.search_genius("The White Stripes", credentials_file=filepath)
genius_songs = spotfuncs.get_songs(artist_id, credentials_file=filepath)

# %%
name = genius_songs[0][0]
url = genius_songs[0][2]

lyrics = spotfuncs.get_lyrics(url)

print(name, '\n')
print(lyrics)
# Out:
# 300 M.P.H. Torrential Outpour Blues
#
# ...

# %%
genius_songs
# Out:
# [['300 M.P.H. Torrential Outpour Blues',
#   447938,
#   'https://genius.com/The-white-stripes-300-mph-torrential-outpour-blues-lyrics'],
#  ["A Boy's Best Friend",
#   447843,
#   'https://genius.com/The-white-stripes-a-boys-best-friend-lyrics'],
#  ['Aluminum', 447917, 'https://genius.com/The-white-stripes-aluminum-lyrics'],
#  ['A Martyr For My Love For You',
#   341766,
#   'https://genius.com/The-white-stripes-a-martyr-for-my-love-for-you-lyrics'],
#  ['Apple Blossom',
#   447821,
#   'https://genius.com/The-white-stripes-apple-blossom-lyrics'],
#  ['Apple Blossom (Remixed)',
#   2854384,
#   'https://genius.com/The-white-stripes-apple-blossom-remixed-lyrics'],
#  ['Apple Of My Eye',
#   955233,
#   'https://genius.com/The-white-stripes-apple-of-my-eye-lyrics'],
#  ['Ashtray Heart',
#   1534161,
#   'https://genius.com/The-white-stripes-ashtray-heart-lyrics'],
#  ['Astro', 440936, 'https://genius.com/The-white-stripes-astro-lyrics'],
#  ['As Ugly As I Seem',
#   332285,
# ...
